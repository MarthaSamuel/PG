# %% [markdown]
# DESCRIPTION
#
# What to:
#
# You have been provided with a dataset that lists Ohio State’s leading causes of death from the year 2012.
#
# Using the two data points:
#
#     Cause of deaths and
#     Percentile
#     Draw a pie chart to visualize the dataset

# %% [markdown]
# #### 1: List the causes of death and percentile in Ohio state in the year 2012

# %%
#import required libraries
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#cause of deaths
cause=['Chronic Disease', 'Unintentional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis','Others']
#percentile
percentile=[62, 5, 4, 2, 1 , 26]

# %% [markdown]
# #### 2: Draw a pie chart using the two data points

# %%
#set the pie chart plot properties
plt.figure(figsize=(9,9))
explode=(0.04,0,0.0,0.0,0.0,0)
plt.pie(percentile,labels=cause,explode=explode,autopct='%1.1f%%',startangle=90)
plt.title('Ohio State’s leading causes of death from the year 2012')
plt.show()
